# %%
from sabr import SABR
sabr_example = SABR('CU')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1046/1046 [01:46<00:00,  9.79it/s]

# %%
sabr_example.black_scholes()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 113764/113764 [02:10<00:00, 871.36it/s]

# %%
sabr_example.sabr_calification()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2092/2092 [23:52<00:00,  1.46it/s]

# %%
sabr_para_first = sabr_example.first_sabr_para
sabr_para_second = sabr_example.second_sabr_para

# %%
sabr_para_first.std()
# Out:
# alpha     0.170598
# beta      0.000000
# rho       0.330980
# volvol    0.023919
# dtype: float64

# %%
sabr_para_first.mean()
# Out:
# alpha     0.549873
# beta      0.500000
# rho       0.455522
# volvol    0.006337
# dtype: float64

# %%
sabr_para_second.std()
# Out:
# alpha     0.115508
# beta      0.000000
# rho       0.251722
# volvol    0.001288
# dtype: float64

# %%
sabr_para_second.mean()
# Out:
# alpha     0.521618
# beta      0.500000
# rho       0.565853
# volvol    0.002307
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(15, 10), sharex=True)

# Plot alpha
axs[0].plot(sabr_para_first.index, sabr_para_first['alpha'], color='blue')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)

# Plot rho
axs[1].plot(sabr_para_first.index, sabr_para_first['rho'], color='red')
axs[1].set_ylabel('Rho')
axs[1].grid(True)

# Plot volvol
axs[2].plot(sabr_para_first.index, sabr_para_first['volvol'], color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
plt.savefig(f"image/SABR parameters of main constarct.png")
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(15, 10), sharex=True)

# Plot alpha
axs[0].plot(sabr_para_second.index, sabr_para_second['alpha'], color='blue')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)

# Plot rho
axs[1].plot(sabr_para_second.index, sabr_para_second['rho'], color='red')
axs[1].set_ylabel('Rho')
axs[1].grid(True)

# Plot volvol
axs[2].plot(sabr_para_second.index, sabr_para_second['volvol'], color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
plt.savefig(f"image/SABR parameters of second constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first['alpha'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Alpha Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Alpha Distribution of main constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first['rho'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Rho Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Rho Distribution of main constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first['volvol'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Volvol Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Volvol Distribution of main constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_second['alpha'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Alpha Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Alpha Distribution of second constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_second['rho'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Rho Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Rho Distribution of second constarct.png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_second['volvol'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Volvol Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Volvol Distribution of second constarct.png")
plt.show()

# %%
sabr_para_first_cleaned = sabr_para_first.copy()
mask = ((sabr_para_first_cleaned['alpha'] > 1.2) | (sabr_para_first_cleaned['alpha'] < 0.2)) | (sabr_para_first_cleaned['volvol'] > 0.025)
sabr_para_first_cleaned.loc[mask, :] = np.nan

# %%
mask.sum()
# Out:
# 16

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first_cleaned['alpha'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Alpha Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Alpha Distribution of main constarct(cleaned).png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first_cleaned['rho'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Rho Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Rho Distribution of main constarct(cleaned).png")
plt.show()

# %%
# 假设data_list是一个包含数值的列表
data_list = sabr_para_first_cleaned['volvol'].values

# 使用直方图绘制数据分布
plt.hist(data_list, bins='auto', alpha=0.7, color='blue', edgecolor='black')

# 添加标题和坐标轴标签
plt.title('Volvol Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Volvol Distribution of main constarct(cleaned).png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(15, 10), sharex=True)

# Plot alpha
axs[0].plot(sabr_para_first_cleaned.index, sabr_para_first_cleaned['alpha'], color='blue')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)

# Plot rho
axs[1].plot(sabr_para_first_cleaned.index, sabr_para_first_cleaned['rho'], color='red')
axs[1].set_ylabel('Rho')
axs[1].grid(True)

# Plot volvol
axs[2].plot(sabr_para_first_cleaned.index, sabr_para_first_cleaned['volvol'], color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
plt.savefig(f"image/SABR parameters of main constarct(cleaned).png")
plt.show()

# %%
all_option = sabr_example.option_all.forward.groupby(['date','underlyingid']).first().values
first_forward = all_option[::2]
second_forward = all_option[1::2]
date_lst = sabr_example.date_lst
first_tau = sabr_example.first_tau
second_tau = sabr_example.second_tau

# %%
# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# Plot alpha
axs[0].plot(date_lst, first_forward, color='blue')
axs[0].set_ylabel('first_forward')
axs[0].grid(True)

# Plot rho
axs[1].plot(date_lst, second_forward, color='red')
axs[1].set_ylabel('second_forward')
axs[1].grid(True)

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
plt.savefig(f"image/Forward price of futures.png")
plt.show()

# %%
np.corrcoef(first_forward,date_lst_re)
# Out:
# array([[1.        , 0.69073549],
#        [0.69073549, 1.        ]])

# %%
np.corrcoef(first_forward,first_tau)
# Out:
# array([[ 1.        , -0.09293468],
#        [-0.09293468,  1.        ]])

# %%
from statsmodels.tsa.stattools import adfuller #ADF单位根检验
option_all_cali = sabr_example.option_all_cali.copy()
option_all_cali['real_ret'] = option_all_cali.settle.groupby(['underlyingid','strike']).transform(lambda x:x/x.shift(1)-1)
date_train = sabr_example.date_lst[:-20]
date_test = sabr_example.date_lst[-20:]

# %%
first_forward
# Out:
# array([49240., 48940., 48680., ..., 78650., 79320., 80400.])

# %%
import pandas as pd
# 1、单变量ARIMA：
# 1.1：first_forward
first_forward_ts = pd.Series(first_forward,index = sabr_example.date_lst,name = 'first_forward')
first_forward_train = first_forward_ts[date_train]
first_forward_test = first_forward_ts[date_test]

# %%
plt.figure(figsize=(12, 5))
# 使用直方图绘制数据分布
plt.plot(first_forward_train)

# 添加标题和坐标轴标签
plt.title('Forward of main constarct')
plt.xlabel('date')
plt.ylabel('Forward')
plt.grid(True)
# 显示图形
plt.savefig(f"image/Forward of main constarct.png")
plt.show()

# %%
# 首先检查是否存在ARCH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
from arch.unitroot import engle_granger

# 假设你的时间序列数据存储在名为 df 的 DataFrame 中，其中包含名为 'returns' 的列，表示收益率数据

# # 绘制波动图
# plt.figure(figsize=(12, 6))
# plt.plot(df['returns'])
# plt.xlabel('时间')
# plt.ylabel('收益率')
# plt.title('收益率波动图')
# plt.grid(True)
# plt.show()

# # 绘制自相关图（ACF）
# plt.figure(figsize=(12, 6))
# plot_acf(df['returns'], lags=40, ax=plt.gca())
# plt.xlabel('滞后数')
# plt.ylabel('自相关系数')
# plt.title('自相关图（ACF）')
# plt.grid(True)
# plt.show()

# 进行统计检验，如 LB 检验
lb_test = acf(first_forward_train, fft=False, nlags=20)
p_values = lb_test[1:]
critical_value = 1.96 / np.sqrt(len(first_forward_train))
print("LB 检验结果：")
print("p-values:", p_values)
print("Critical Value:", critical_value)
# Out:
# LB 检验结果：
# p-values: [0.9961514  0.9914695  0.98663452 0.98167435 0.97657653 0.97152841
#  0.96653146 0.96137396 0.9563985  0.9513489  0.94649782 0.94183349
#  0.9371531  0.93230947 0.92750682 0.92250557 0.91690407 0.91144316
#  0.90600949 0.90081916]
# Critical Value: 0.06119027302333734

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# 假设你的时间序列数据存储在名为 df 的 DataFrame 中，其中包含名为 'value' 的列
# 如果你的数据不是 DataFrame 格式，你需要将其转换为 DataFrame 格式
# df = pd.DataFrame({'value': your_time_series_data})

# 绘制自相关图（ACF）
# plt.figure(figsize=(12, 6))
plot_acf(first_forward_train, lags=40, ax=plt.gca())
plt.xlabel('lags')
plt.ylabel('autocorrelation coefficient')
plt.title('ACF')
plt.grid(True)
plt.savefig(f"image/ARIMA-ACF.png")
plt.show()

# 绘制偏自相关图（PACF）
# plt.figure(figsize=(12, 6))
plot_pacf(first_forward_train, lags=40, ax=plt.gca())
plt.xlabel('lags')
plt.ylabel('partial autocorrelation coefficient')
plt.title('PACF')
plt.grid(True)
plt.savefig(f"image/ARIMA-PACF.png")
plt.show()

# %%
# 绘制自相关图（ACF）
# plt.figure(figsize=(12, 6))
plot_acf(first_forward_train.diff().dropna(), lags=40, ax=plt.gca())
plt.xlabel('lags')
plt.ylabel('autocorrelation coefficient')
plt.title('ACF')
plt.grid(True)
plt.savefig(f"image/ARIMA-ACF-d1.png")
plt.show()

# 绘制偏自相关图（PACF）
# plt.figure(figsize=(12, 6))
plot_pacf(first_forward_train.diff().dropna(), lags=40, ax=plt.gca())
plt.xlabel('lags')
plt.ylabel('partial autocorrelation coefficient')
plt.title('PACF')
plt.grid(True)
plt.savefig(f"image/ARIMA-PACF-d1.png")
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
best_aic = float("inf")
best_model = None
best_p = None
best_q = None
for p in range(3):
    for q in range(3):
        try:
            model = ARIMA(first_forward_train, order=(p, 1, q))
            result = model.fit()
            aic = result.aic
            if aic < best_aic:
                best_aic = aic
                best_model = result
                best_p = p
                best_q = q
        except:
            continue

print("Best AIC:", best_aic)
print("Best p:", best_p)
print("Best q:", best_q)
print(best_model.summary())
# Out:
# Best AIC: 16048.819037358771
# Best p: 0
# Best q: 1
#                                SARIMAX Results
# ...
# Dep. Variable:          first_forward   No. Observations:                 1026
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8022.410
# Date:                Sun, 05 May 2024   AIC                          16048.819
# Time:                        22:11:23   BIC                          16058.684
# Sample:                             0   HQIC                         16052.564
#                                - 1026
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1144      0.014      8.329      0.000       0.087       0.141
# sigma2      3.649e+05   1.04e+04     35.082      0.000    3.45e+05    3.85e+05
# ...
# Ljung-Box (L1) (Q):                   3.74   Jarque-Bera (JB):               395.31
# ...

# %%
forecast = best_model.predict(start=0, end=len(first_forward_train) - 1)
# 绘制原始数据和拟合数据的图形
plt.figure(figsize=(10, 6))
plt.plot(first_forward_train, label='real data')
plt.plot(forecast[1:], label='fit data', color='red')
plt.xlabel('date')
plt.ylabel('forward')
plt.title('real vs fit data')
plt.legend()
plt.grid(True)
plt.savefig(f"image/ARIMA-real vs fit data.png")
plt.show()

# %%
import warnings

# 忽略特定类型的警告
warnings.filterwarnings("ignore")

# %%
from statsmodels.tsa.arima.model import ARIMA
# 初始化预测结果列表
predictions = []

# 用于滚动预测的历史数据列表
history = first_forward_train.values.tolist()

# 对测试集进行滚动预测
for t in range(len(first_forward_test)):
    # 使用历史数据进行预测
    model = ARIMA(history, order=(best_p, 1, best_q))
    model_fit = model.fit()
    prediction = model_fit.forecast(steps=1, typ='levels')[0]
    predictions.append(prediction)
    # 将测试集中的真实值添加到历史数据中
    history.append(first_forward_test[t])

# 将预测结果转换为Series，以便与测试集进行比较
predictions_series = pd.Series(predictions, index=first_forward_test.index)

# 绘制实际值和预测值
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(first_forward_test, label='real data')
plt.plot(predictions_series, label='predict data')
plt.xlabel('date')
plt.ylabel('forward')
plt.title('real vs predict data')
plt.legend()
plt.grid(True)
plt.savefig(f"image/ARIMA-real vs predict data.png")
plt.show()

# 评估模型性能，例如使用均方误差(MSE)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(first_forward_test, predictions_series)
print('Test MSE: ', mse)
# Out:
# Test MSE:  573960.5899155107

# %%
model.order
# Out:
# (0, 1, 1)

# %%
import pmdarima as pm
 
model = pm.auto_arima(first_forward_train.values, start_p=1, start_q=1,
                      information_criterion='aic',
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
 
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16051.829, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16066.546, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16050.159, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16049.852, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16065.904, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=16051.843, Time=0.41 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16053.848, Time=1.51 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=16048.819, Time=0.22 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=16050.801, Time=0.70 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=16050.821, Time=0.29 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=16049.092, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=16052.665, Time=0.43 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 5.058 seconds
#                                SARIMAX Results
# ...

# %%
second_forward_ts = pd.Series(second_forward,index = sabr_example.date_lst,name = 'second_forward')
first_forward_ts = pd.Series(first_forward,index = sabr_example.date_lst,name = 'first_forward')

# %%
from importlib import reload
import predict  
reload(predict)
from predict import _ARIMA

example_1 = _ARIMA(first_forward_train,first_forward_test)
main_forward_fit, main_forward_predict= example_1.get_predict_data()
ARIMA_first_forward = pd.concat([main_forward_fit, main_forward_predict],axis=0)
ARIMA_first_forward.name = 'ARIMA_first_forward'

example_2 = _ARIMA(second_forward_ts[date_train],second_forward_ts[date_test])
second_forward_fit, second_forward_predict= example_2.get_predict_data()
ARIMA_second_forward = pd.concat([second_forward_fit, second_forward_predict],axis=0)
ARIMA_second_forward.name = 'ARIMA_second_forward'

for name in ['alpha','rho','volvol']:
    example_1 = _ARIMA(sabr_para_first_cleaned.loc[date_train,name],sabr_para_first_cleaned.loc[date_test,name])
    main_forward_fit, main_forward_predict= example_1.get_predict_data()
    ARIMA_first_forward = pd.concat([main_forward_fit, main_forward_predict],axis=0)
    ARIMA_first_forward.name = f'ARIMA_{name}'
    sabr_para_first_cleaned[f'ARIMA_{name}'] = ARIMA_first_forward

    example_2 = _ARIMA(sabr_para_second.loc[date_train,name],sabr_para_second.loc[date_test,name])
    second_forward_fit, second_forward_predict= example_2.get_predict_data()
    ARIMA_second_forward = pd.concat([second_forward_fit, second_forward_predict],axis=0)
    ARIMA_second_forward.name = f'ARIMA_{name}'
    sabr_para_second[f'ARIMA_{name}'] = ARIMA_second_forward
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=16051.829, Time=1.26 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=16066.546, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=16050.159, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=16049.852, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=16065.904, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=16051.843, Time=0.30 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=16053.848, Time=1.60 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=16048.819, Time=0.24 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=16050.801, Time=0.79 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=16050.821, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=16049.092, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=16052.665, Time=0.56 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 5.580 seconds
# Performing stepwise search to minimize aic
# ...

# %%
first_forward_df = pd.concat([first_forward_ts,ARIMA_first_forward],axis = 1)
second_forward_df = pd.concat([second_forward_ts,ARIMA_second_forward],axis = 1)

# %%
first_forward_df.to_excel('first_forward.xlsx')
second_forward_df.to_excel('second_forward.xlsx')
sabr_para_first_cleaned.to_excel('sabr_para_first.xlsx')
sabr_para_second.to_excel('sabr_para_second.xlsx')

# %%
from statsmodels.stats.diagnostic import acorr_ljungboxdd
acorr_ljungbox(best_model.resid)
# Out:
#      lb_stat  lb_pvalue
# 1   0.587097   0.443544
# 2   0.587281   0.745544
# 3   0.606694   0.894898
# 4   0.606996   0.962283
# 5   0.613732   0.987366
# 6   0.653859   0.995433
# 7   0.681134   0.998477
# 8   0.682405   0.999569
# 9   0.740028   0.999839
# 10  0.754166   0.999954

# %%
# Create subplots
fig, axs = plt.subplots(3, 1, figsize=(15, 10), sharex=True)

# Plot alpha
axs[0].plot(sabr_para_first_cleaned.alpha[-20:], label='real data', color='red')
axs[0].plot(sabr_para_first_cleaned.ARIMA_alpha[-20:], label='predict data', color='green')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)
axs[0].legend()
# Plot rho
axs[1].plot(sabr_para_first_cleaned.rho[-20:], label='real data', color='red')
axs[1].plot(sabr_para_first_cleaned.ARIMA_rho[-20:], label='predict data', color='green')
axs[1].set_ylabel('Rho')
axs[1].grid(True)
axs[1].legend()
# Plot volvol
axs[2].plot(sabr_para_first_cleaned.volvol[-20:], label='real data', color='red')
axs[2].plot(sabr_para_first_cleaned.ARIMA_volvol[-20:], label='predict data', color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
axs[2].legend()
plt.savefig(f"image/ARIMA-real vs predict SABR parameters.png")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(sabr_para_first_cleaned.alpha[-20:], label='real data')
plt.plot(sabr_para_first_cleaned.ARIMA_alpha[-20:], label='predict data')
plt.xlabel('date')
plt.ylabel('alpha')
plt.title('real vs predict alpha')
plt.legend()
plt.grid(True)
plt.savefig(f"image/ARIMA-real vs predict data.png")
plt.show()

# %%
first_forward
second_forward
sabr_para_first_cleaned
sabr_para_second
# Out:
#                alpha  beta       rho    volvol
# 2020-01-02  0.281492   0.5  0.633913  0.000925
# 2020-01-03  0.286290   0.5  0.609082  0.000973
# 2020-01-06  0.292437   0.5  0.164377  0.002809
# 2020-01-07  0.301886   0.5  0.324991  0.002086
# 2020-01-08  0.290493   0.5  0.175006  0.002547
# ...              ...   ...       ...       ...
# 2024-04-22  0.657570   0.5  0.313115  0.003973
# 2024-04-23  0.591558   0.5  0.516536  0.002028
# 2024-04-24  0.600440   0.5  0.551809  0.001950
# 2024-04-25  0.608584   0.5  0.989922  0.001107
# 2024-04-26  0.641799   0.5  0.649253  0.001779
#
# [1046 rows x 4 columns]

# %%
LSTM_data = option_all_cali[['options_tau','forward']].groupby(['date','type']).first()
LSTM_data_first = LSTM_data[LSTM_data.index.get_level_values('type')==0]
LSTM_data_first = LSTM_data_first.droplevel(level=['type'])
LSTM_data_first = pd.concat([LSTM_data_first,sabr_para_first_cleaned[['alpha','rho','volvol']]],axis = 1)

# %%
LSTM_data_first.dropna()
# Out:
#             options_tau  forward     alpha       rho    volvol
# 2020-01-02           18  49240.0  0.349024  0.108037  0.002685
# 2020-01-03           52  49070.0  0.321953  0.703685  0.002008
# 2020-01-06           49  48810.0  0.328828  0.002846  0.013250
# 2020-01-07           48  48880.0  0.328262 -0.007500  0.013733
# 2020-01-08           47  48810.0  0.316760 -0.004298  0.018022
# ...                 ...      ...       ...       ...       ...
# 2024-04-22           35  80080.0  0.731282  0.298985  0.004590
# 2024-04-23           34  78860.0  0.648239  0.281081  0.003947
# 2024-04-24           33  78650.0  0.638818  0.690951  0.001708
# 2024-04-25           32  79320.0  0.639182  0.288612  0.003799
# 2024-04-26           31  80400.0  0.693593  0.400002  0.003061
#
# [1030 rows x 5 columns]

# %%
PRED_SIZE = 1 #Forecast output 1-day sequence data
TIME_STEPS = 20


def get_batch(train_x,train_y,TIME_STEPS = 20):
    data_len = len(train_x) - TIME_STEPS+1 # may exist some problem;only suit for pred_size = 1
    seq = []
    res = []
    for i in range(data_len):
        seq.append(train_x[i:i + TIME_STEPS])
        res.append(train_y[i:i + TIME_STEPS]) #取后5组数据
        #res.append(train_y[i:i + TIME_STEPS]) 

    seq ,res = np.array(seq),np.array(res)

    return  seq, res

def get_test_train_data(df_data):
    sc = MinMaxScaler(feature_range= (0,1))# scale
    df_data = df_data.dropna()
    training_set = sc.fit_transform(df_data[:-20])
    test_set = sc.transform(df_data[-20:])
    total_set = np.concatenate([training_set,test_set], axis=0)
    # Since it is for multiple periods of time, the data needs to be fetched separately.
    seq, res = get_batch(total_set[:-PRED_SIZE], total_set[PRED_SIZE:,1:])
    train_seq = seq[:-20]
    train_res = res[:-20]
    test_seq = seq[-20:]
    test_res = res[-20:]
    return train_seq,train_res,test_seq,test_set[:,0],sc,df_data[-20:]

# %%
BATCH_START = 0
BATCH_SIZE = 25
INPUT_SIZE = 5 # four para and ond date(maybe more thing)
OUTPUT_SIZE = 4
CELL_SIZE = 24
LR = 0.1
EPOSE = 100

class KerasMultiLSTM(object):

    def __init__(self,n_steps, input_size, output_size, cell_size, batch_size,drop_lr):
        self.n_steps = n_steps
        self.input_size = input_size
        self.output_size = output_size
        self.cell_size = cell_size # LSTM神经单元数      
        self.batch_size = batch_size # 输入batch_size大小
        self.drop_lr = drop_lr
    
    def model(self):
        
        self.model = Sequential() 
                
        # 不固定batch_size，预测时可以以1条记录进行分析
        self.model.add(LSTM(units = self.cell_size,  activation='tanh', return_sequences = True , 
                            input_shape = (self.n_steps, self.input_size))
        )
        self.model.add(Dropout(self.drop_lr))        
        self.model.add(LSTM(units = self.cell_size, activation='tanh', return_sequences = True))
        self.model.add(Dropout(self.drop_lr))        
        # self.model.add(LSTM(units = self.cell_size, activation='relu', return_sequences = True))
        # self.model.add(Dropout(0.1))

        #全连接，输出， add output layer
        self.model.add(TimeDistributed(Dense(self.output_size)))
        self.model.compile(metrics=['mean_squared_error'], loss='mean_squared_error', optimizer='adam')
        self.model.summary()
    
    def train(self,x_train,y_train, epochs ,filename):
        history = self.model.fit(x_train, y_train, epochs = epochs, batch_size = self.batch_size).history
        self.model.save(filename)        
        return history

# %%
from sklearn.preprocessing import MinMaxScaler # scaler
from tensorflow.keras.layers import LSTM,TimeDistributed,Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model

train_x,train_y,test_x,test_y,sc,test_df = get_test_train_data(LSTM_data_first)
# 训练集需要是batch_size的倍数
k = len(train_x)%BATCH_SIZE
train_x,train_y = train_x[k:], train_y[k:]

model = KerasMultiLSTM(TIME_STEPS, INPUT_SIZE, OUTPUT_SIZE, CELL_SIZE, BATCH_SIZE,LR)
model.model()
history = model.train(train_x,train_y,EPOSE,"lstm-model.keras")

plt.plot(history['loss'], linewidth=2, label='Train')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.savefig(f"image/LSTM_learning.png")
plt.show()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_44 (LSTM)              (None, 20, 24)            2880
#
#  dropout_44 (Dropout)        (None, 20, 24)            0
#
#  lstm_45 (LSTM)              (None, 20, 24)            4704
#
#  dropout_45 (Dropout)        (None, 20, 24)            0
#
#  time_distributed_22 (TimeDi  (None, 20, 4)            100
#  stributed)
#
# ...
# Total params: 7,684
# Trainable params: 7,684
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 39/39 [==============================] - 3s 10ms/step - loss: 0.2417 - mean_squared_error: 0.2417
# Epoch 2/100
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0964 - mean_squared_error: 0.0964
# Epoch 3/100
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0603 - mean_squared_error: 0.0603
# Epoch 4/100
# ...

# %%
train_x,train_y,test_x,test_y,sc,test_df = get_test_train_data(LSTM_data_first)
model = load_model('lstm-model.keras')
pred = model.predict(test_x)
def get_pred_data(pred,text_y,sc):
    pred_neu = pred[:,-1,:]
    text_y_neu = np.array([np.array([elem]) for elem in test_y])
    yy = np.concatenate((text_y_neu, pred_neu),axis = 1)
    y=sc.inverse_transform(yy)
    return y
pred_array = get_pred_data(pred,test_y,sc)
pred_df = pd.DataFrame(pred_array,columns = test_df.columns)
pred_df.index = test_df.index
# Out:
# 1/1 [==============================] - 0s 442ms/step

# %%
pred_df
# Out:
#             options_tau       forward     alpha       rho    volvol
# 2024-03-28    46.884069  70692.710586  0.406059  0.383755  0.003675
# 2024-03-29    47.052356  70777.584329  0.396006  0.354663  0.003930
# 2024-04-01    47.602094  70877.306972  0.394115  0.337373  0.004035
# 2024-04-02    47.916230  70512.178463  0.412034  0.329620  0.003826
# 2024-04-03    48.499626  70805.116117  0.442528  0.347656  0.003553
# 2024-04-08    50.507853  71507.829393  0.466536  0.378741  0.003335
# 2024-04-09    51.506358  73483.436029  0.510205  0.432797  0.002714
# 2024-04-10    51.775617  74240.397638  0.563132  0.424509  0.002546
# 2024-04-11    51.427823  74404.832894  0.568738  0.442360  0.002483
# 2024-04-12    51.551234  74506.549416  0.541301  0.486346  0.002299
# 2024-04-15    52.381451  74626.913728  0.526748  0.526529  0.002039
# 2024-04-16    52.403889  74134.418423  0.533115  0.494423  0.002076
# 2024-04-17    51.887809  74377.860539  0.546808  0.493498  0.002083
# ...

# %%
# Create subplots
fig, axs = plt.subplots(4, 1, figsize=(20, 10), sharex=True)

# Plot alpha
axs[0].plot(LSTM_data_first.alpha[-20:], label='real data', color='red')
axs[0].plot(pred_df.alpha, label='predict data', color='green')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)
axs[0].legend()
# Plot rho
axs[1].plot(LSTM_data_first.rho[-20:], label='real data', color='red')
axs[1].plot(pred_df.rho, label='predict data', color='green')
axs[1].set_ylabel('Rho')
axs[1].grid(True)
axs[1].legend()
# Plot volvol
axs[2].plot(LSTM_data_first.volvol[-20:], label='real data', color='red')
axs[2].plot(pred_df.volvol, label='predict data', color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)
axs[2].legend()
# Plot volvol
axs[3].plot(LSTM_data_first.forward[-20:], label='real data', color='red')
axs[3].plot(pred_df.forward, label='predict data', color='green')
axs[3].set_ylabel('Forward')
axs[3].grid(True)
axs[3].legend()

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot

plt.savefig(f"image/LSTM-real vs predict.png")
plt.show()

# %%
def get_test_train_data_Forward(df_data,TIME_STEPS = 10):
    sc = MinMaxScaler(feature_range= (0,1))# scale
    df_data = df_data.dropna()
    training_set = sc.fit_transform(df_data[:-20])
    test_set = sc.transform(df_data[-20:])
    total_set = np.concatenate([training_set,test_set], axis=0)
    # Since it is for multiple periods of time, the data needs to be fetched separately.
    seq, res = get_batch(total_set[:-PRED_SIZE], total_set[PRED_SIZE:,1],TIME_STEPS = TIME_STEPS)
    train_seq = seq[:-20]
    train_res = res[:-20]
    test_seq = seq[-20:]
    test_res = res[-20:]
    return train_seq,train_res,test_seq,test_set[:,[0,2,3,4]],sc,df_data[-20:]

# %%
OUTPUT_SIZE = 1
INPUT_SIZE = 5
TIME_STEPS = 20
BATCH_SIZE = 16
train_x,train_y,test_x,test_y,sc,test_index = get_test_train_data_Forward(LSTM_data_first,TIME_STEPS)

LR = 0.2
# 训练集需要是batch_size的倍数
k = len(train_x)%BATCH_SIZE
train_x,train_y = train_x[k:], train_y[k:]

model_forward = KerasMultiLSTM(TIME_STEPS, INPUT_SIZE, OUTPUT_SIZE, CELL_SIZE, BATCH_SIZE,LR)
model_forward.model()
history = model_forward.train(train_x,train_y,EPOSE,"lstm-model_forward.keras")

plt.plot(history['loss'], linewidth=2, label='Train')
plt.legend(loc='upper right')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.savefig(f"image/LSTM_learning_forward.png")
plt.show()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_52 (LSTM)              (None, 20, 24)            2880
#
#  dropout_52 (Dropout)        (None, 20, 24)            0
#
#  lstm_53 (LSTM)              (None, 20, 24)            4704
#
#  dropout_53 (Dropout)        (None, 20, 24)            0
#
#  time_distributed_26 (TimeDi  (None, 20, 1)            25
#  stributed)
#
# ...
# Total params: 7,609
# Trainable params: 7,609
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 61/61 [==============================] - 8s 22ms/step - loss: 0.1251 - mean_squared_error: 0.1251
# Epoch 2/100
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0437 - mean_squared_error: 0.0437
# Epoch 3/100
# 61/61 [==============================] - 1s 22ms/step - loss: 0.0301 - mean_squared_error: 0.0301
# Epoch 4/100
# ...

# %%
train_x,train_y,test_x,test_y,sc,test_df = get_test_train_data_Forward(LSTM_data_first,TIME_STEPS)
model = load_model('lstm-model_forward.keras')
pred = model.predict(test_x)
def get_pred_data_forward(pred,test_y,sc):
    pred_neu = pred[:,-1,:]
    test_y_neu = np.array([np.array([elem]) for elem in test_y[:,0]])
    yy = np.concatenate((test_y_neu, pred_neu,test_y[:,1:]),axis = 1)
    y=sc.inverse_transform(yy)
    return y
pred_array = get_pred_data_forward(pred,test_y,sc)
pred_df = pd.DataFrame(pred_array,columns = test_df.columns)
pred_df.index = date_test
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
# Create subplots
fig, axs = plt.subplots(4, 1, figsize=(20, 10), sharex=True)

# Plot alpha
axs[0].plot(LSTM_data_first.alpha[-20:], label='real data', color='red')
axs[0].plot(pred_df.alpha, label='predict data', color='green')
axs[0].set_ylabel('Alpha')
axs[0].grid(True)
axs[0].legend()
# Plot rho
axs[1].plot(LSTM_data_first.rho[-20:], label='real data', color='red')
axs[1].plot(pred_df.rho, label='predict data', color='green')
axs[1].set_ylabel('Rho')
axs[1].grid(True)
axs[1].legend()
# Plot volvol
axs[2].plot(LSTM_data_first.volvol[-20:], label='real data', color='red')
axs[2].plot(pred_df.volvol, label='predict data', color='green')
axs[2].set_ylabel('Volvol')
axs[2].grid(True)
axs[2].legend()
# Plot volvol
axs[3].plot(LSTM_data_first.forward[-20:], label='real data', color='red')
axs[3].plot(pred_df.forward, label='predict data', color='green')
axs[3].set_ylabel('Forward')
axs[3].grid(True)
axs[3].legend()

# Set common x-axis label
axs[-1].set_xlabel('Date')

# Adjust layout
plt.tight_layout()
# Show plot
plt.show()

# %%
test_y
# Out:
# array([[0.44444444, 0.1586267 , 0.67415693, 0.08939184],
#        [0.42222222, 0.19126714, 0.74852215, 0.06357106],
#        [0.35555556, 0.23130039, 0.62799642, 0.11507816],
#        [0.33333333, 0.24857555, 0.58470006, 0.13358916],
#        [0.31111111, 0.25690329, 0.69337659, 0.08117007],
#        [0.93333333, 0.28036695, 0.53041191, 0.24018643],
#        [0.91111111, 0.37277332, 0.4813756 , 0.25367622],
#        [0.88888889, 0.3361376 , 0.61554945, 0.16319199],
#        [0.86666667, 0.28706372, 0.77325034, 0.07132362],
#        [0.84444444, 0.32443484, 0.96588422, 0.03773127],
#        [0.77777778, 0.34315647, 0.71420237, 0.09504834],
#        [0.75555556, 0.36276419, 0.77242506, 0.07476163],
#        [0.73333333, 0.31692698, 0.61729811, 0.14685818],
#        [0.71111111, 0.37728335, 0.65689744, 0.13062943],
#        [0.68888889, 0.45614444, 0.76624011, 0.08723358],
#        [0.62222222, 0.56952393, 0.63458684, 0.19664647],
# ...
