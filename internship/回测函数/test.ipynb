# %%
import sys
sys.path.append('/home/wangs/rs/lib')
import ff
from timed_backtesting import double_line_strategy

# %%
factor = ff.read('TPS_RC')
example_1 = double_line_strategy(factor.shift(1,axis=0))
example_1.performance()
# Out:
# {'年化收益率': 0.01690986560226145, '年化波动率': 0.22908873151152304, '夏普率': 0.07381360702768085, '最大回撤': -0.9452549111018885, '收益回撤比': 0.017889212109513962, '胜率': 0.498, '盈亏比': 1.0206466372443057}

# %%
factor = ff.read('SPS_RC')
example_1 = double_line_strategy(factor.shift(1,axis=0))
example_1.performance()
# Out:
# {'年化收益率': 0.0190075386610252, '年化波动率': 0.25465382206683224, '夏普率': 0.07464069656114093, '最大回撤': -0.8898777035560378, '收益回撤比': 0.021359720088579844, '胜率': 0.515, '盈亏比': 0.9543780808248058}

# %%
1.TPS_SPS
ff.save('TPS_RC',TPS)
ff.save('SPS_RC',SPS)
2.
